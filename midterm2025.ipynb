# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanniix22/dataviz2025/blob/main/midterm2025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ให้สืบหาฆาตรกร (10 คะแนน) และ ผู้บงการ (5 คะแนน) ในคดี ฆาตรกรรม (murder) ที่เกิดขึ้นในวันที่ 15 มกราคม 2018 ที่เมือง Pandas City โดยเริ่มจากการตรวจสอบ ข้อมูลคดีในไฟล์ crime_scene_report.csv

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
crime_scene=pd.read_csv('/content/drive/MyDrive/examdata/crime_scene_report.csv')

# %%
crime_scene
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# ...

# %%
# กรองเฉพาะคดี murder ที่ Pandas City วันที่ 20180115
murder_case = crime_scene[(crime_scene["date"] == 20180115) &
                 (crime_scene["city"] == "Pandas City") &
                    (crime_scene["type"] == "murder")]
murder_case[["date", "city", "type", "description"]]
# Out:
#           date         city    type  \
# 1227  20180115  Pandas City  murder
#
#                                             description
# 1227  Security footage shows that there were 2 witne...

# %%
persons=pd.read_csv('/content/drive/MyDrive/examdata/person.csv')
persons
# Out:
#           id                 name  license_id  address_number  \
# 0      10000   Christoper Peteuil      993845             624
# 1      10007  Kourtney Calderwood      861794            2791
# 2      10010            Muoi Cary      385336             741
# 3      10016          Era Moselle      431897            1987
# 4      10025         Trena Hornby      550890             276
# ...      ...                  ...         ...             ...
# 10006  99936          Luba Benser      274427             680
# 10007  99941      Roxana Mckimley      975942            1613
# 10008  99965      Cherie Zeimantz      287627            3661
# 10009  99982          Allen Cruse      251350            3126
# 10010  99990         Vance Hunten      830407            3056
#
#       address_street_name        ssn
# 0            Bankhall Ave  747714076
# 1           Gustavus Blvd  477972044
# 2         Northwestern Dr  828638512
# 3           Wood Glade St  614621061
# ...

# %%
# หาคนที่อยู่บน Northwestern Dr
northwestern = persons[persons["address_street_name"].str.contains("Northwestern Dr", na=False)]

# หาคนที่อยู่บน Franklin Ave และชื่อ Annabel
annabel = persons[(persons["address_street_name"].str.contains("Franklin Ave", na=False)) &
                  (persons["name"].str.contains("Annabel", na=False))]

print("\n พยาน Annabel บน Franklin Ave")
display(annabel)
# Out:
#  พยาน Annabel บน Franklin Ave
#         id            name  license_id  address_number address_street_name  \
# 665  16371  Annabel Miller      490173             103        Franklin Ave
#
#            ssn
# 665  318771143

# %%
interview = pd.read_csv('/content/drive/MyDrive/examdata/interview.csv')
interview
# Out:
#       person_id                                         transcript
# 0         28508                ‘I deny it!’ said the March Hare.\n
# 1         63713                                                 \n
# 2         86208      way, and the whole party swam to the shore.\n
# 3         35267  lessons in here? Why, there’s hardly room for ...
# 4         33856                                                 \n
# ...         ...                                                ...
# 4986      37357  Alice did not wish to offend the Dormouse agai...
# 4987      10206  time,’ she said, ‘than waste it in asking ridd...
# 4988      14887  I heard a gunshot and then saw a man run out. ...
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...
#
# [4991 rows x 2 columns]

# %%
annabel_interview = interview[interview['person_id'] == 16371]
annabel_interview
# Out:
#       person_id                                         transcript
# 4989      16371  I saw the murder happen, and I recognized the ...

# %%
checkin = pd.read_csv('/content/drive/MyDrive/examdata/get_fit_now_check_in.csv')
checkin
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 0            NL318       20180212            329             365
# 1            NL318       20170811            469             920
# 2            NL318       20180429            506             554
# 3            NL318       20180128            124             759
# 4            NL318       20171027            418            1019
# ...            ...            ...            ...             ...
# 2698         4KB72       20170422           1016            1114
# 2699         4KB72       20170630            408             885
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700
#
# [2703 rows x 4 columns]

# %%
c9 = checkin[checkin['check_in_date'] == 20180109]
c9
# Out:
#      membership_id  check_in_date  check_in_time  check_out_time
# 113          X0643       20180109            957            1164
# 889          UK1F2       20180109            344             518
# 1329         XTE42       20180109            486            1124
# 1446         1AE2H       20180109            461             944
# 1703         6LSTG       20180109            399             515
# 2137         7MWHJ       20180109            273             885
# 2435         GE5Q8       20180109            367             959
# 2700         48Z7A       20180109           1600            1730
# 2701         48Z55       20180109           1530            1700
# 2702         90081       20180109           1600            1700

# %%
member = pd.read_csv('/content/drive/MyDrive/examdata/get_fit_now_member.csv')
member
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# ...

# %%
c9_people = (
    c9.merge(member, left_on='membership_id', right_on='id', how='left')
      .merge(persons, left_on='person_id', right_on='id', how='left', suffixes=('','_person'))
      [['membership_id','person_id','name','check_in_date']]
      .drop_duplicates()
      .rename(columns={'name':'full_name'})
)
c9_people
# Out:
#   membership_id  person_id          full_name  check_in_date
# 0         X0643      15247     Shondra Ledlow       20180109
# 1         UK1F2      28073   Zackary Cabotage       20180109
# 2         XTE42      55662     Sarita Bartosh       20180109
# 3         1AE2H      10815   Adriane Pelligra       20180109
# 4         6LSTG      83186      Burton Grippe       20180109
# 5         7MWHJ      31523  Blossom Crescenzo       20180109
# 6         GE5Q8      92736      Carmen Dimick       20180109
# 7         48Z7A      28819       Joe Germuska       20180109
# 8         48Z55      67318      Jeremy Bowers       20180109
# 9         90081      16371     Annabel Miller       20180109

# %%
attendee_ids        = set(c9_people['person_id'].unique())
attendee_interviews = interview[interview['person_id'].isin(attendee_ids)]
annabel_interview   = interview[interview['person_id']==16371]

attendee_interviews
# Out:
#       person_id                                         transcript
# 2133      28073  of tiny white kid gloves: she took up the fan ...
# 4574      92736                            ‘Yes!’ shouted Alice.\n
# 4989      16371  I saw the murder happen, and I recognized the ...
# 4990      67318  I was hired by a woman with a lot of money. I ...

# %% [markdown]
# person_id 67318 คือฆาตกร

# %%
murderer = persons[persons['id'] == 67318]
murderer
# Out:
#          id           name  license_id  address_number    address_street_name  \
# 6327  67318  Jeremy Bowers      423327             530  Washington Pl, Apt 3A
#
#             ssn
# 6327  871539279

# %% [markdown]
# #ฆาตกรคือ Jeremy Bowers

# %% [markdown]
# #หาผู้บงการ
#
# ใช้เงื่อนไขจากคำให้การ:
#
# หญิง, ผมแดง
#
# ส่วนสูง 65–67 นิ้ว
#
# Tesla Model S
#
# ไป SQL Symphony Concert ≥ 3 ครั้งใน ธ.ค. 2017

# %%
dlicense=pd.read_csv('/content/drive/MyDrive/examdata/drivers_license.csv')
dlicense
# Out:
#            id  age  height eye_color hair_color  gender plate_number  \
# 0      100280   72      57     brown        red    male       P24L4U
# 1      100460   63      72     brown      brown  female       XF02T6
# 2      101029   62      74     green      green  female       VKY5KR
# 3      101198   43      54     amber      brown  female       Y5NZ08
# 4      101255   18      79      blue       grey  female       5162Z1
# ...       ...  ...     ...       ...        ...     ...          ...
# 10002  999923   19      77     amber      black  female       5L0ZI4
# 10003  999940   71      61     green      green    male       1B8QN8
# 10004  999981   67      69     brown       blue  female       1684K3
# 10005  999986   49      58     green       grey    male       F8F64H
# 10006  999993   18      63     black      black  female       6UZO2O
#
#          car_make    car_model
# 0           Acura          MDX
# 1        Cadillac          SRX
# 2           Scion           xB
# ...

# %%
boss = dlicense[(dlicense["gender"] == "female") &
                 (dlicense["hair_color"] == "red") &
                    (dlicense["height"] >= 65) & (dlicense["height"] <= 67)&
                    (dlicense["car_make"] == "Tesla")&
                    (dlicense["car_model"] == "Model S")] # Corrected car model capitalization
display(boss)
# Out:
#           id  age  height eye_color hair_color  gender plate_number car_make  \
# 1105  202298   68      66     green        red  female       500123    Tesla
# 2054  291182   65      66      blue        red  female       08CM64    Tesla
# 9078  918773   48      65     black        red  female       917UU3    Tesla
#
#      car_model
# 1105   Model S
# 2054   Model S
# 9078   Model S

# %%
fb = pd.read_csv('/content/drive/MyDrive/examdata/facebook_event_checkin.csv')
fb
# Out:
#        person_id  event_id                                         event_name  \
# 0          28508      5880    Nudists are people who wear one-button suits.\n
# 1          63713      3865  but that's because it's the best book on anyth...
# 2          63713      3999           If Murphy's Law can go wrong, it will.\n
# 3          63713      6436  Old programmers never die.  They just branch t...
# 4          82998      4470               Help a swallow land at Capistrano.\n
# ...          ...       ...                                                ...
# 20006      99716      1143                               SQL Symphony Concert
# 20007      99716      1143                               SQL Symphony Concert
# 20008      99716      1143                               SQL Symphony Concert
# 20009      67318      4719                             The Funky Grooves Tour
# 20010      67318      1143                               SQL Symphony Concert
#
#            date
# ...

# %%
# Filter by date range (December 2017) using integer comparison and event name
mask_date = (fb['date'] >= 20171201) & (fb['date'] <= 20171231)
mask_event = fb['event_name'].str.contains('SQL Symphony Concert', case=False, na=False)

sql_dec = fb[mask_date & mask_event]

# Count check-ins per person_id
counts = sql_dec.groupby('person_id').size().reset_index(name='checkins')

# Filter for those who checked in >= 3 times
mastermind_candidates = counts[counts['checkins'] >= 3]

display(mastermind_candidates)
# Out:
#     person_id  checkins
# 4       24556         3
# 15      99716         3

# %%
# license_id ของหญิงผมแดงสูง 65–67" Tesla Model S
license_ids = [202298, 291182, 918773]

# คนที่เช็กอิน SQL Symphony Concert ≥3 ครั้ง
concert_ids = [24556, 99716]

# จับคู่ license → person.id
mastermind_candidates = person[person['license_id'].isin(license_ids)]

# กรองให้เหลือเฉพาะที่อยู่ใน concert_ids
final_mastermind = mastermind_candidates[mastermind_candidates['id'].isin(concert_ids)]

print(final_mastermind[['id','name','license_id']])
# Out:
#          id              name  license_id
# 9985  99716  Miranda Priestly      202298

# %% [markdown]
# #ผู้บงการคือ Miranda Priestly

# %% [markdown]
# #ตอบ ฆาตกรคือ Jeremy Bowers ,ผู้บงการคือ Miranda Priestly
